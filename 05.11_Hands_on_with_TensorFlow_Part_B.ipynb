# %% [markdown]
# # __Hands-on with TensorFlow: Part B__
#
# - In this demo, let's see how to implement ensemble techniques using Keras and sklearn.

# %% [markdown]
# ## Step 1: Import the required libraries and load the dataset
#
# - Import necessary libraries from Sklearn, TensorFlow, and Keras.
# - Load the dataset using sklearn's make_moons function.
# - Define X and y and split the dataset into training and testing sets using the train_test_split function.

# %%
# !pip install tensorflow==2.17.0 scikeras==0.13.0 keras==3.2.0
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.5.2
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.17.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2)
# ERROR: No matching distribution found for tensorflow==2.17.0
# Found existing installation: scikit-learn 1.5.1
# Uninstalling scikit-learn-1.5.1:
#   Successfully uninstalled scikit-learn-1.5.1
# Collecting scikit-learn==1.5.2
#   Downloading scikit_learn-1.5.2-cp312-cp312-macosx_10_9_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn==1.5.2) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn==1.5.2) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn==1.5.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn==1.5.2) (3.5.0)
# Downloading scikit_learn-1.5.2-cp312-cp312-macosx_10_9_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 33.5 MB/s eta 0:00:00 0:00:01
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.5.2

# %%
import os

# Disable oneDNN optimizations to avoid potential minor numerical differences caused by floating-point round-off errors.
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

# %%
# Import necessary libraries from Sklearn, TensorFlow, and Keras
import sklearn
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Load the dataset using sklearn's make_moons function
X, y = make_moons(n_samples=500, noise=0.30, random_state=42)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# __Observation:__
# - The necessary libraries and modules have been downloaded.

# %% [markdown]
# ## Step 2: Define classifiers
#
# - Define Logistic Regression, Random Forest, Support Vector Machine, and Keras Neural Network classifiers.

# %%
# Define Logistic Regression, Random Forest, and Support Vector Machine classifiers
log_clf = LogisticRegression(solver="lbfgs", random_state=42)
rnd_clf = RandomForestClassifier(n_estimators=100, random_state=42)
svm_clf = SVC(gamma="scale", random_state=42,probability=True)

# %% [markdown]
# - Import Sequential and Dense modules from the TensorFlow library to create a neural network.
# - Define the function build_nn() to build a neural network.

# %%
# %pip install scikeras==0.13.0

# Import Sequential and Dense modules from the TensorFlow library to create a neural network

import os
from scikeras.wrappers import KerasClassifier
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Define the function to build a neural network
def build_nn():
    model = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(50, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(
        optimizer='Adam',
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return model
# Out:
# Requirement already satisfied: scikeras==0.13.0 in /opt/anaconda3/lib/python3.12/site-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikeras==0.13.0) (3.13.2)
# Requirement already satisfied: scikit-learn>=1.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from scikeras==0.13.0) (1.5.2)
# Requirement already satisfied: absl-py in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.2.0->scikeras==0.13.0) (2.4.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.2.0->scikeras==0.13.0) (1.26.4)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.2.0->scikeras==0.13.0) (13.7.1)
# Requirement already satisfied: namex in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.2.0->scikeras==0.13.0) (0.1.0)
# Requirement already satisfied: h5py in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.2.0->scikeras==0.13.0) (3.11.0)
# Requirement already satisfied: optree in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.2.0->scikeras==0.13.0) (0.19.0)
# Requirement already satisfied: ml-dtypes in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.2.0->scikeras==0.13.0) (0.3.2)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.2.0->scikeras==0.13.0) (24.1)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.4.2->scikeras==0.13.0) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.4.2->scikeras==0.13.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.4.2->scikeras==0.13.0) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from optree->keras>=3.2.0->scikeras==0.13.0) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->scikeras==0.13.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.2.0->scikeras==0.13.0) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras==0.13.0) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
# 2026-03-23 07:26:31.755839: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# - Now, let's wrap scikit learn and build a neural network with 500 epochs with the Keras classifier.

# %%
keras_clf = KerasClassifier(model=build_nn, epochs=500, verbose=False)

# %% [markdown]
# __Observation:__
# - Scikit learn is wrapped.

# %%
keras_clf._estimator_type = "classifier"

# %% [markdown]
# ## Step 3: Create the voting and stacking classifier
#
# - Combine the classifiers using sklearn's VotingClassifier with soft voting.

# %%
# Combine the classifiers using sklearn's VotingClassifier with soft voting
voting = VotingClassifier(
             estimators=[('lr', log_clf),
                         ('rf', rnd_clf),
                         ('svc', svm_clf),
                         ('keras',keras_clf)],
             voting='soft',
             flatten_transform=True)

# %%
from sklearn.ensemble import StackingClassifier

estimators = [('lr', log_clf),
              ('rf', rnd_clf),
              ('svc', svm_clf),
              ('nn', keras_clf)
             ]

stacking_clf = StackingClassifier(
    estimators=estimators,
    final_estimator=log_clf,   # Logistic  as the final meta-learner
    passthrough=True
)

# %% [markdown]
# - The classifiers are combined with soft voting.

# %% [markdown]
# ## Step 4: Train and evaluate the classifiers
#
# - Train the voting classifier and each individual classifier.
# - Make predictions on the test set and calculate the accuracy for each classifier.

# %% [markdown]
# - Consider voting with StackingClassifier and estimator.
# - The first is LogisticRegression, the second is RandomForest, the third is SVM, the fourth is KerasClassifier, and the fifth is StackingClassifier.

# %%
models = {
    "Logistic Regression": log_clf,
    "Random Forest": rnd_clf,
    "SVC": svm_clf,
    "Neural Network": keras_clf,
    "Stacking Classifier": stacking_clf
}

for name, clf in models.items():
    clf.fit(X_train, y_train)
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x165c62ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x165c62ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
from sklearn.metrics import accuracy_score

print("Model Evaluation")
for name, clf in models.items():
    y_pred = clf.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    print(f"{name}: Test Accuracy = {acc:.3f}")
# Out:
# Model Evaluation
# Logistic Regression: Test Accuracy = 0.864
# Random Forest: Test Accuracy = 0.896
# SVC: Test Accuracy = 0.896
# Neural Network: Test Accuracy = 0.896
# Stacking Classifier: Test Accuracy = 0.912

# %% [markdown]
# __Observation:__
#
# - As shown above, the accuracy for each classifier models can be seen.

# %% [markdown]
# **Visualization of Decision Boundaries**

# %%
# Function to plot decision boundaries
def plot_decision_boundary(clf, X, y, ax, title):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),
                         np.arange(y_min, y_max, 0.01))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=0.3)
    ax.scatter(X[:, 0], X[:, 1], c=y, edgecolor='k', marker='o')
    ax.set_title(title)

# Plot decision boundaries for each classifier
fig, axes = plt.subplots(3, 2, figsize=(15, 20))

plot_decision_boundary(log_clf, X_test, y_test, axes[0, 0], "Logistic Regression")
plot_decision_boundary(rnd_clf, X_test, y_test, axes[0, 1], "Random Forest")
plot_decision_boundary(svm_clf, X_test, y_test, axes[1, 0], "Support Vector Machine")
plot_decision_boundary(keras_clf, X_test, y_test, axes[1, 1], "Keras Neural Network")
voting.fit(X_train, y_train)
plot_decision_boundary(voting, X_test, y_test, axes[2, 0], "Voting Classifier")

# Hide empty subplot
axes[2, 1].axis('off')

plt.show()

# %% [markdown]
# **Observation:**
#
# The decision boundaries for each classifier are visualized, showing how each model classifies the data.
